# %%
from sklearn.model_selection import train_test_split

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib.pyplot as pt

# %%
# %matplotlib inline

# %%
#importing data set

# %%
fmpstrain=pd.read_csv("C:/Users/ADMIN/Downloads/mobile price/train (1).csv")

# %%
fmpstrain
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %%
fmpstrain.shape
# Out:
# (2000, 21)

# %%
fmpstrain.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   battery_power  2000 non-null   int64
#  1   blue           2000 non-null   int64
#  2   clock_speed    2000 non-null   float64
#  3   dual_sim       2000 non-null   int64
#  4   fc             2000 non-null   int64
#  5   four_g         2000 non-null   int64
#  6   int_memory     2000 non-null   int64
#  7   m_dep          2000 non-null   float64
#  8   mobile_wt      2000 non-null   int64
#  9   n_cores        2000 non-null   int64
#  10  pc             2000 non-null   int64
#  11  px_height      2000 non-null   int64
#  12  px_width       2000 non-null   int64
#  13  ram            2000 non-null   int64
#  14  sc_h           2000 non-null   int64
#  15  sc_w           2000 non-null   int64
#  16  talk_time      2000 non-null   int64
#  17  three_g        2000 non-null   int64
# ...

# %%
newdataset2=fmpstrain.drop(['battery_power','blue','clock_speed','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt','n_cores','px_height','px_width','sc_h','sc_w','talk_time','three_g','touch_screen','wifi'],axis=1)

# %%
newdataset2
# Out:
#       pc   ram  price_range
# 0      2  2549            1
# 1      6  2631            2
# 2      6  2603            2
# 3      9  2769            2
# 4     14  1411            1
# ...   ..   ...          ...
# 1995  14   668            0
# 1996   3  2032            2
# 1997   3  3057            3
# 1998   5   869            0
# 1999  16  3919            3
#
# [2000 rows x 3 columns]

# %% [raw]
# #reshape our data

# %%
x=newdataset2.iloc[:,0].values.reshape(-1,1)
y=newdataset2.iloc[:,1].values.reshape(-1,1)

# %%
x
# Out:
# array([[ 2],
#        [ 6],
#        [ 6],
#        ...,
#        [ 3],
#        [ 5],
#        [16]], dtype=int64)

# %%
y
# Out:
# array([[2549],
#        [2631],
#        [2603],
#        ...,
#        [3057],
#        [ 869],
#        [3919]], dtype=int64)

# %%
newdataset2=fmpstrain.drop(['battery_power','blue','clock_speed','dual_sim','fc','four_g','int_memory','m_dep','mobile_wt','n_cores','px_height','px_width','sc_h','sc_w','talk_time','three_g','touch_screen','wifi'],axis=1)

# %%
newdataset2
# Out:
#       pc   ram  price_range
# 0      2  2549            1
# 1      6  2631            2
# 2      6  2603            2
# 3      9  2769            2
# 4     14  1411            1
# ...   ..   ...          ...
# 1995  14   668            0
# 1996   3  2032            2
# 1997   3  3057            3
# 1998   5   869            0
# 1999  16  3919            3
#
# [2000 rows x 3 columns]

# %%
pt.scatter(x,y)
pt.xlabel('ram')
pt.ylabel('price_range')
pt.show()

# %%
#spliting the data

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,train_size=0.5,random_state=0)

# %%
x_test.shape
# Out:
# (1000, 1)

# %%
y_train.shape
# Out:
# (1000, 1)

# %%
x_train.shape
# Out:
# (1000, 1)

# %%
y_test.shape
# Out:
# (1000, 1)

# %%
#linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_predict=lr.predict(x_test)

# %%
y_predict
# Out:
# array([[2060.35984115],
#        [2120.70433819],
#        [2049.38811442],
#        [2098.76088472],
#        [2049.38811442],
#        [2098.76088472],
#        [2098.76088472],
#        [2137.1619283 ],
#        [2065.84570452],
#        [2142.64779166],
#        [2142.64779166],
#        [2087.78915799],
#        [2065.84570452],
#        [2126.19020156],
#        [2049.38811442],
#        [2093.27502136],
#        [2071.33156789],
#        [2131.67606493],
#        [2071.33156789],
#        [2120.70433819],
#        [2104.24674809],
#        [2148.13365503],
#        [2148.13365503],
#        [2137.1619283 ],
#        [2098.76088472],
#        [2049.38811442],
#        [2065.84570452],
#        [2049.38811442],
#        [2115.21847483],
#        [2043.90225105],
#        [2043.90225105],
#        [2115.21847483],
#        [2087.78915799],
#        [2104.24674809],
#        [2109.73261146],
#        [2054.87397778],
#        [2137.1619283 ],
#        [2065.84570452],
# ...

# %%
DATAS=pd.DataFrame(x_test,columns=['price_range'])

# %%
DATAS
# Out:
#      price_range
# 0              3
# 1             14
# 2              1
# 3             10
# 4              1
# ..           ...
# 995            3
# 996           20
# 997            5
# 998           20
# 999           12
#
# [1000 rows x 1 columns]

# %%
DATAS['predicted']=y_predict

# %%
DATAS
# Out:
#      price_range    predicted
# 0              3  2060.359841
# 1             14  2120.704338
# 2              1  2049.388114
# 3             10  2098.760885
# 4              1  2049.388114
# ..           ...          ...
# 995            3  2060.359841
# 996           20  2153.619518
# 997            5  2071.331568
# 998           20  2153.619518
# 999           12  2109.732611
#
# [1000 rows x 2 columns]

# %%
pt.scatter(x,y,color='purple')
pt.plot(x_test,y_predict,color='blue')
pt.show()
